# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %%
def system(v, t):
    v1, v2, v3 = v
    dv1dt = v1 * v3
    dv2dt = -v2 * v3
    dv3dt = -v1**2 + v2**2
    return [dv1dt, dv2dt, dv3dt]


initial_settings = [
    [-0.71, -0.99], 
    [0.18, -0.85],
    [-0.75, 0.19],
    [0.10, 0.27]]


t = np.linspace(0, 30, 10000)

plt.figure(figsize=(10, 6))


for i, v0 in enumerate(initial_settings, start=1):

    v0 = [1.0, 0.1*v0[0], 1.0*v0[1]]
    v = odeint(system, v0, t)

    plt.plot(t, v[:, 0], label=f"${{v_1}}$ (Initial Condition {i})")


plt.xlabel('Time')
plt.ylabel('Amplitude $v_1$')
plt.title('Kraichnan-Orszag Three-Mode Problem')
plt.legend()
plt.grid(True)
plt.show()
