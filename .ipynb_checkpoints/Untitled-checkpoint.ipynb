# %% [markdown]
# ## Set up

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %%
def system(v, t):
    v1, v2, v3 = v
    dv1dt = v1 * v3
    dv2dt = -v2 * v3
    dv3dt = -v1**2 + v2**2
    return [dv1dt, dv2dt, dv3dt]


initial_settings = [
    [-0.71, -0.99], 
    [0.18, -0.85],
    [-0.75, 0.19],
    [0.10, 0.27]]


t = np.linspace(0, 30, 10000)

plt.figure(figsize=(10, 6))

dataset = []

for i, v0 in enumerate(initial_settings, start=1):

    v0 = [1.0, 0.1*v0[0], 1.0*v0[1]]
    v = odeint(system, v0, t)

    dataset.append(v[:, 0])
    plt.plot(t, v[:, 0], label=f"({10*v0[1]:.2f}, {v0[2]:.2f})")
    
dataset = np.array(dataset)


plt.xlabel('Time')
plt.ylabel('Amplitude $v_1$')
plt.title('Kraichnan-Orszag Three-Mode Problem')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Parameter Sampling

# %%
def sample_point():
    x = np.random.uniform(-1, 1)
    y = np.random.uniform(-1, 1)
    return x, y


num_samples = 10


x_points = np.empty(num_samples)
y_points = np.empty(num_samples)


for i in range(num_samples):
    x, y = sample_point()
    x_points[i] = x
    y_points[i] = y


plt.scatter(x_points, y_points, s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.title('2D Uniformly Distributed Points')
plt.grid(True)
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %%
initial_settings = np.vstack((x_points, y_points)).T

# %%
def system(v, t):
    v1, v2, v3 = v
    dv1dt = v1 * v3
    dv2dt = -v2 * v3
    dv3dt = -v1**2 + v2**2
    return [dv1dt, dv2dt, dv3dt]


# initial_settings = [
#     [-0.71, -0.99], 
#     [0.18, -0.85],
#     [-0.75, 0.19],
#     [0.10, 0.27]]


t = np.linspace(0, 30, 10000)

dataset = []

# for i, v0 in enumerate(initial_settings, start=1):
for i in range(len(initial_settings)):

    v0 = initial_settings[i]
    v0 = [1.0, 0.1*v0[0], 1.0*v0[1]]
    v = odeint(system, v0, t)

    dataset.append(v[:, 0])
    
dataset = np.array(dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 dataset = generate_solutions(initial_settings)
#
# NameError: name 'generate_solutions' is not defined

# %% [markdown]
# ## Dimension Reduction

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans


pca = PCA(n_components=50)
PCA_reduced_data = pca.fit_transform(dataset)

n_clusters = 5
kmeans = KMeans(n_clusters=n_clusters)
PCA_labels = kmeans.fit_predict(PCA_reduced_data)
# Out:
# /home/gulio/anaconda3/envs/23_09/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
pca.inverse_transform(PCA_reduced_data).shape
# Out:
# (1024, 10000)

# %%
plt.scatter(x_points, y_points, c=PCA_labels, cmap='viridis', s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.title('PCA    ' + 'Number of clusters: ' + f"{n_clusters}")
plt.grid(True)
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %%
from sklearn.manifold import TSNE


tsne = TSNE(n_components=2, perplexity=30, n_iter=300, random_state=42)
reduced_data = tsne.fit_transform(dataset)

n_clusters = 5
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
TSNE_labels = kmeans.fit_predict(reduced_data)

plt.scatter(reduced_data[:, 0], reduced_data[:, 1], c=TSNE_labels, cmap='viridis', s=5)
plt.title('K-Means Clustering Results after t-SNE')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()
# Out:
# /home/gulio/anaconda3/envs/23_09/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
plt.scatter(x_points, y_points, c=TSNE_labels, cmap='viridis', s=5)
plt.xlabel('x')
plt.ylabel('y')
plt.title('t-SNE    ' + 'Number of clusters: ' + f"{n_clusters}")
plt.grid(True)
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %%
PCA_reduced_data.shape
initial_settings.shape
# Out:
# (1024, 2)

# %% [markdown]
# ## Single GP

# %%
import torch
import gpytorch
from gpytorch.means import ConstantMean
from gpytorch.kernels import RBFKernel
from gpytorch.likelihoods import GaussianLikelihood
from gpytorch.distributions import MultivariateNormal
from gpytorch.mlls import ExactMarginalLogLikelihood

# %%
train_x = torch.tensor(initial_settings).float()
train_y = torch.tensor(PCA_reduced_data).float()

class MultiOutputGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(MultiOutputGPModel, self).__init__(train_x, train_y, likelihood)
        
        self.mean_module = gpytorch.means.ConstantMean(batch_shape=torch.Size([50]))
        self.covar_module = gpytorch.kernels.ScaleKernel(
            gpytorch.kernels.RBFKernel(batch_shape=torch.Size([50])),
            batch_shape=torch.Size([50])
        )
        
    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultitaskMultivariateNormal.from_batch_mvn(
            gpytorch.distributions.MultivariateNormal(mean_x, covar_x)
        )

likelihood = gpytorch.likelihoods.MultitaskGaussianLikelihood(num_tasks=50)
model = MultiOutputGPModel(train_x, train_y, likelihood)

model.train()
likelihood.train()


optimizer = torch.optim.Adam(model.parameters(), lr=0.1)

mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

training_iter = 50
for i in range(training_iter):
    optimizer.zero_grad()
    output = model(train_x)
    loss = -mll(output, train_y)
    loss.backward()
    optimizer.step()
    print('Iter %d/%d - Loss: %.3f' % (i + 1, training_iter, loss.item()))
# Out:
# Iter 1/50 - Loss: 6.404
# Iter 2/50 - Loss: 5.923
# Iter 3/50 - Loss: 5.466
# Iter 4/50 - Loss: 5.046
# Iter 5/50 - Loss: 4.664
# Iter 6/50 - Loss: 4.321
# Iter 7/50 - Loss: 4.014
# Iter 8/50 - Loss: 3.736
# Iter 9/50 - Loss: 3.485
# Iter 10/50 - Loss: 3.261
# Iter 11/50 - Loss: 3.058
# Iter 12/50 - Loss: 2.879
# Iter 13/50 - Loss: 2.723
# Iter 14/50 - Loss: 2.587
# Iter 15/50 - Loss: 2.470
# Iter 16/50 - Loss: 2.372
# Iter 17/50 - Loss: 2.290
# Iter 18/50 - Loss: 2.221
# Iter 19/50 - Loss: 2.165
# Iter 20/50 - Loss: 2.119
# Iter 21/50 - Loss: 2.083
# Iter 22/50 - Loss: 2.052
# Iter 23/50 - Loss: 2.030
# Iter 24/50 - Loss: 2.013
# Iter 25/50 - Loss: 2.001
# Iter 26/50 - Loss: 1.991
# Iter 27/50 - Loss: 1.984
# Iter 28/50 - Loss: 1.978
# Iter 29/50 - Loss: 1.973
# Iter 30/50 - Loss: 1.968
# Iter 31/50 - Loss: 1.963
# Iter 32/50 - Loss: 1.957
# Iter 33/50 - Loss: 1.950
# Iter 34/50 - Loss: 1.943
# Iter 35/50 - Loss: 1.934
# Iter 36/50 - Loss: 1.925
# Iter 37/50 - Loss: 1.915
# Iter 38/50 - Loss: 1.905
# Iter 39/50 - Loss: 1.895
# Iter 40/50 - Loss: 1.885
# Iter 41/50 - Loss: 1.874
# Iter 42/50 - Loss: 1.864
# Iter 43/50 - Loss: 1.854
# Iter 44/50 - Loss: 1.843
# Iter 45/50 - Loss: 1.833
# Iter 46/50 - Loss: 1.824
# Iter 47/50 - Loss: 1.813
# Iter 48/50 - Loss: 1.803
# Iter 49/50 - Loss: 1.794
# Iter 50/50 - Loss: 1.786

# %%
model.eval()
likelihood.eval()

test_param = [0.18, -0.85]

test_x = torch.tensor([
    test_param
]).float()

with torch.no_grad(), gpytorch.settings.fast_pred_var():
    observed_pred = likelihood(model(test_x))

# %%
reconstructed = pca.inverse_transform(observed_pred.mean)[0]

v0 = [1.0, 0.1*test_param[0], 1.0*test_param[1]]
v = odeint(system, v0, t)

plt.title(f'Parameter: {test_param}')
plt.xlabel('Time')
plt.ylabel('Amplitude $v_1$')
plt.plot(t, v[:, 0], label="Ground Truth")
plt.plot(t, reconstructed, label="Test Result")
plt.legend()
plt.show()

# %% [markdown]
# ## Multiple GPs: 5 clusters

# %%
# plt.scatter(initial_settings[:, 0], initial_settings[:, 1], c=PCA_labels, cmap='viridis', s=5)

for label in np.unique(PCA_labels):
    mask = PCA_labels == label
    plt.scatter(initial_settings[mask, 0], initial_settings[mask, 1], cmap='viridis', s=5, label=f'Cluster {label}')


plt.xlabel('x')
plt.ylabel('y')
plt.title('PCA    ' + 'Number of clusters: ' + f"{n_clusters}")
plt.grid(True)
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.gca().set_aspect('equal', adjustable='box')
plt.legend(title='Clusters', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
initial_settings.shape

partitioned_initial_settings = []
partitioned_PCA_reduced_data = []

for label in range(n_clusters):
    partition = initial_settings[PCA_labels == label]
    partitioned_initial_settings.append(partition)
    partitioned_PCA_reduced_data.append(PCA_reduced_data[PCA_labels == label])

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(initial_settings, PCA_labels)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
test_param = [0.18, -0.85]

point = np.array([test_param])
selected_cluster = knn.predict(point)[0]
print('selected_cluster: ', selected_cluster)
# Out:
# selected_cluster:  2

# %%
train_x = torch.tensor(partitioned_initial_settings[selected_cluster]).float()
train_y = torch.tensor(partitioned_PCA_reduced_data[selected_cluster]).float()

class MultiOutputGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(MultiOutputGPModel, self).__init__(train_x, train_y, likelihood)
        
        self.mean_module = gpytorch.means.ConstantMean(batch_shape=torch.Size([50]))
        self.covar_module = gpytorch.kernels.ScaleKernel(
            gpytorch.kernels.RBFKernel(batch_shape=torch.Size([50])),
            batch_shape=torch.Size([50])
        )
        
    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultitaskMultivariateNormal.from_batch_mvn(
            gpytorch.distributions.MultivariateNormal(mean_x, covar_x)
        )

likelihood = gpytorch.likelihoods.MultitaskGaussianLikelihood(num_tasks=50)
model = MultiOutputGPModel(train_x, train_y, likelihood)

model.train()
likelihood.train()


optimizer = torch.optim.Adam(model.parameters(), lr=0.1)

mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

training_iter = 50
for i in range(training_iter):
    optimizer.zero_grad()
    output = model(train_x)
    loss = -mll(output, train_y)
    loss.backward()
    optimizer.step()
    print('Iter %d/%d - Loss: %.3f' % (i + 1, training_iter, loss.item()))
# Out:
# Iter 1/50 - Loss: 2.452
# Iter 2/50 - Loss: 2.378
# Iter 3/50 - Loss: 2.280
# Iter 4/50 - Loss: 2.198
# Iter 5/50 - Loss: 2.127
# Iter 6/50 - Loss: 2.067
# Iter 7/50 - Loss: 2.015
# Iter 8/50 - Loss: 1.971
# Iter 9/50 - Loss: 1.932
# Iter 10/50 - Loss: 1.897
# Iter 11/50 - Loss: 1.863
# Iter 12/50 - Loss: 1.829
# Iter 13/50 - Loss: 1.796
# Iter 14/50 - Loss: 1.763
# Iter 15/50 - Loss: 1.731
# Iter 16/50 - Loss: 1.698
# Iter 17/50 - Loss: 1.664
# Iter 18/50 - Loss: 1.629
# Iter 19/50 - Loss: 1.594
# Iter 20/50 - Loss: 1.557
# Iter 21/50 - Loss: 1.522
# Iter 22/50 - Loss: 1.485
# Iter 23/50 - Loss: 1.448
# Iter 24/50 - Loss: 1.409
# Iter 25/50 - Loss: 1.373
# Iter 26/50 - Loss: 1.333
# Iter 27/50 - Loss: 1.295
# Iter 28/50 - Loss: 1.256
# Iter 29/50 - Loss: 1.217
# Iter 30/50 - Loss: 1.178
# Iter 31/50 - Loss: 1.138
# Iter 32/50 - Loss: 1.098
# Iter 33/50 - Loss: 1.054
# Iter 34/50 - Loss: 1.013
# Iter 35/50 - Loss: 0.972
# Iter 36/50 - Loss: 0.927
# Iter 37/50 - Loss: 0.880
# Iter 38/50 - Loss: 0.836
# Iter 39/50 - Loss: 0.798
# Iter 40/50 - Loss: 0.753
# Iter 41/50 - Loss: 0.713
# Iter 42/50 - Loss: 0.669
# Iter 43/50 - Loss: 0.632
# Iter 44/50 - Loss: 0.593
# Iter 45/50 - Loss: 0.562
# Iter 46/50 - Loss: 0.540
# Iter 47/50 - Loss: 0.540
# Iter 48/50 - Loss: 0.518
# Iter 49/50 - Loss: 0.481
# Iter 50/50 - Loss: 0.440

# %%
model.eval()
likelihood.eval()

test_x = torch.tensor([
    test_param
]).float()

with torch.no_grad(), gpytorch.settings.fast_pred_var():
    observed_pred = likelihood(model(test_x))
    

reconstructed = pca.inverse_transform(observed_pred.mean)[0]

v0 = [1.0, 0.1*test_param[0], 1.0*test_param[1]]
v = odeint(system, v0, t)

plt.title(f'Parameter: {test_param}')
plt.xlabel('Time')
plt.ylabel('Amplitude $v_1$')
plt.plot(t, v[:, 0], label="Ground Truth")
plt.plot(t, reconstructed, label="Test Result")
plt.legend()
plt.show()

# %% [markdown]
# ## Multiple GPs: 20 clusters

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans


pca = PCA(n_components=50)
PCA_reduced_data = pca.fit_transform(dataset)

n_clusters = 20
kmeans = KMeans(n_clusters=n_clusters)
PCA_labels = kmeans.fit_predict(PCA_reduced_data)

if PCA_reduced_data.shape[1] == 2:
    plt.scatter(PCA_reduced_data[:, 0], PCA_reduced_data[:, 1], c=labels, cmap='viridis', s=5)
    plt.title('K-Means Clustering Results')
    plt.xlabel('Principal Component 1')
    plt.ylabel('Principal Component 2')
    plt.show()
# Out:
# /home/gulio/anaconda3/envs/23_09/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# plt.scatter(initial_settings[:, 0], initial_settings[:, 1], c=PCA_labels, cmap='viridis', s=5)

for label in np.unique(PCA_labels):
    mask = PCA_labels == label
    plt.scatter(initial_settings[mask, 0], initial_settings[mask, 1], cmap='viridis', s=5, label=f'Cluster {label}')


plt.xlabel('x')
plt.ylabel('y')
plt.title('PCA    ' + 'Number of clusters: ' + f"{n_clusters}")
plt.grid(True)
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.gca().set_aspect('equal', adjustable='box')
plt.legend(title='Clusters', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
initial_settings.shape

partitioned_initial_settings = []
partitioned_PCA_reduced_data = []

for label in range(n_clusters):
    partition = initial_settings[PCA_labels == label]
    partitioned_initial_settings.append(partition)
    partitioned_PCA_reduced_data.append(PCA_reduced_data[PCA_labels == label])

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(initial_settings, PCA_labels)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
test_param = [0.18, -0.85]

point = np.array([test_param])
selected_cluster = knn.predict(point)[0]
print('selected_cluster: ', selected_cluster)
# Out:
# selected_cluster:  5

# %%
train_x = torch.tensor(partitioned_initial_settings[selected_cluster]).float()
train_y = torch.tensor(partitioned_PCA_reduced_data[selected_cluster]).float()

class MultiOutputGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(MultiOutputGPModel, self).__init__(train_x, train_y, likelihood)
        
        self.mean_module = gpytorch.means.ConstantMean(batch_shape=torch.Size([50]))
        self.covar_module = gpytorch.kernels.ScaleKernel(
            gpytorch.kernels.RBFKernel(batch_shape=torch.Size([50])),
            batch_shape=torch.Size([50])
        )
        
    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultitaskMultivariateNormal.from_batch_mvn(
            gpytorch.distributions.MultivariateNormal(mean_x, covar_x)
        )

likelihood = gpytorch.likelihoods.MultitaskGaussianLikelihood(num_tasks=50)
model = MultiOutputGPModel(train_x, train_y, likelihood)

model.train()
likelihood.train()


optimizer = torch.optim.Adam(model.parameters(), lr=0.1)

mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

training_iter = 50
for i in range(training_iter):
    optimizer.zero_grad()
    output = model(train_x)
    loss = -mll(output, train_y)
    loss.backward()
    optimizer.step()
    print('Iter %d/%d - Loss: %.3f' % (i + 1, training_iter, loss.item()))
# Out:
# Iter 1/50 - Loss: 1.812
# Iter 2/50 - Loss: 1.762
# Iter 3/50 - Loss: 1.700
# Iter 4/50 - Loss: 1.644
# Iter 5/50 - Loss: 1.592
# Iter 6/50 - Loss: 1.540
# Iter 7/50 - Loss: 1.491
# Iter 8/50 - Loss: 1.448
# Iter 9/50 - Loss: 1.398
# Iter 10/50 - Loss: 1.351
# Iter 11/50 - Loss: 1.309
# Iter 12/50 - Loss: 1.267
# Iter 13/50 - Loss: 1.224
# Iter 14/50 - Loss: 1.181
# Iter 15/50 - Loss: 1.140
# Iter 16/50 - Loss: 1.097
# Iter 17/50 - Loss: 1.056
# Iter 18/50 - Loss: 1.015
# Iter 19/50 - Loss: 0.970
# Iter 20/50 - Loss: 0.932
# Iter 21/50 - Loss: 0.891
# Iter 22/50 - Loss: 0.850
# Iter 23/50 - Loss: 0.817
# Iter 24/50 - Loss: 0.767
# Iter 25/50 - Loss: 0.728
# Iter 26/50 - Loss: 0.690
# Iter 27/50 - Loss: 0.645
# Iter 28/50 - Loss: 0.609
# Iter 29/50 - Loss: 0.572
# Iter 30/50 - Loss: 0.530
# Iter 31/50 - Loss: 0.487
# Iter 32/50 - Loss: 0.445
# Iter 33/50 - Loss: 0.410
# Iter 34/50 - Loss: 0.378
# Iter 35/50 - Loss: 0.337
# Iter 36/50 - Loss: 0.307
# Iter 37/50 - Loss: 0.255
# Iter 38/50 - Loss: 0.234
# Iter 39/50 - Loss: 0.194
# Iter 40/50 - Loss: 0.168
# Iter 41/50 - Loss: 0.128
# Iter 42/50 - Loss: 0.102
# Iter 43/50 - Loss: 0.055
# Iter 44/50 - Loss: 0.017
# Iter 45/50 - Loss: -0.017
# Iter 46/50 - Loss: -0.030
# Iter 47/50 - Loss: -0.049
# Iter 48/50 - Loss: -0.077
# Iter 49/50 - Loss: -0.101
# Iter 50/50 - Loss: -0.162

# %%
model.eval()
likelihood.eval()

test_x = torch.tensor([
    test_param
]).float()

with torch.no_grad(), gpytorch.settings.fast_pred_var():
    observed_pred = likelihood(model(test_x))
    

reconstructed = pca.inverse_transform(observed_pred.mean)[0]

v0 = [1.0, 0.1*test_param[0], 1.0*test_param[1]]
v = odeint(system, v0, t)

plt.title(f'Parameter: {test_param}')
plt.xlabel('Time')
plt.ylabel('Amplitude $v_1$')
plt.plot(t, v[:, 0], label="Ground Truth")
plt.plot(t, reconstructed, label="Test Result")
plt.legend()
plt.show()
